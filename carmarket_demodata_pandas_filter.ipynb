# %% [markdown]
# # Sample Jupyter Notebook to study filtering from dataframes
#
# Data source: Comprehensive Car Market Analysis
# https://www.kaggle.com/datasets/lalit7881/comprehensive-car-market-analysis/data
# Copyright status: CC0 Public Domain

# %%
import pandas as pd

df_carsales = pd.read_csv('data/v1-legacy-carapi-datafeed-sample.csv')

# %%
# data sanity check
df_carsales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17707 entries, 0 to 17706
# Data columns (total 57 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Make Id                                      17707 non-null  int64
#  1   Make Name                                    17707 non-null  object
#  2   Model Id                                     17707 non-null  int64
#  3   Model Name                                   17707 non-null  object
#  4   Trim Id                                      17707 non-null  int64
#  5   Trim Year                                    17707 non-null  int64
#  6   Trim Name                                    17707 non-null  object
#  7   Trim Description                             17707 non-null  object
#  8   Trim Msrp                                    17707 non-null  int64
# ...

# %%
df_carsales.head()
# Out:
#    Make Id Make Name  Model Id Model Name  Trim Id  Trim Year  \
# 0        1     Acura        97        ILX     6292       2020
# 1        1     Acura        97        ILX     6295       2020
# 2        1     Acura        97        ILX     6293       2020
# 3        1     Acura        97        ILX     6296       2020
# 4        1     Acura        97        ILX     6294       2020
#
#                         Trim Name  \
# 0                            Base
# 1     Premium and A-SPEC Packages
# 2                 Premium Package
# 3  Technology and A-SPEC Packages
# 4              Technology Package
#
#                                     Trim Description  Trim Msrp  Trim Invoice  \
# 0                          4dr Sedan (2.4L 4cyl 8AM)      25900       24617.0
# 1  Premium and A-SPEC Packages 4dr Sedan (2.4L 4c...      29750       28264.0
# 2          Premium Package 4dr Sedan (2.4L 4cyl 8AM)      27750       26370.0
# ...

# %%
df_carsales.index
# Out:
# RangeIndex(start=0, stop=17707, step=1)

# %%
#basic selection
#output: dataframe
df_carsales[["Make Name","Model Id"]]
# Out:
#       Make Name  Model Id
# 0         Acura        97
# 1         Acura        97
# 2         Acura        97
# 3         Acura        97
# 4         Acura        97
# ...         ...       ...
# 17702     Volvo       589
# 17703     Volvo       589
# 17704     Volvo       589
# 17705     Volvo       589
# 17706     Volvo       589
#
# [17707 rows x 2 columns]

# %%
type(df_carsales[["Make Name","Model Id"]])
# Out:
# pandas.core.frame.DataFrame

# %%
#position based selection
# scalar value
df_carsales.iloc[2,2]
# Out:
# np.int64(97)

# %%
#all rows from the second column
df_carsales.iloc[:, 1]
# Out:
# 0        Acura
# 1        Acura
# 2        Acura
# 3        Acura
# 4        Acura
#          ...
# 17702    Volvo
# 17703    Volvo
# 17704    Volvo
# 17705    Volvo
# 17706    Volvo
# Name: Make Name, Length: 17707, dtype: object

# %%
#all columns
df_carsales.iloc[0:]
# Out:
#        Make Id Make Name  Model Id Model Name  Trim Id  Trim Year  \
# 0            1     Acura        97        ILX     6292       2020
# 1            1     Acura        97        ILX     6295       2020
# 2            1     Acura        97        ILX     6293       2020
# 3            1     Acura        97        ILX     6296       2020
# 4            1     Acura        97        ILX     6294       2020
# ...        ...       ...       ...        ...      ...        ...
# 17702       23     Volvo       589       XC70    23951       2015
# 17703       23     Volvo       589       XC70    23950       2015
# 17704       23     Volvo       589       XC70    23949       2015
# 17705       23     Volvo       589       XC70    23954       2015
# 17706       23     Volvo       589       XC70    23953       2015
#
#                             Trim Name  \
# 0                                Base
# 1         Premium and A-SPEC Packages
# 2                     Premium Package
# ...

# %%
#finding special elements
#first and second rows, last and last but one columns as dataframes
df_carsales.iloc[[0,1],[-1,-2]]
# Out:
#    Mileage Battery Capacity Electric  \
# 0                                NaN
# 1                                NaN
#
#    Mileage Epa Time To Charge Hr 240v Electric
# 0                                          NaN
# 1                                          NaN
